# %% [markdown]
# WEEK 3: Deep Learning Introduction
#
# • Learn neural network basics
#
# • Set up TensorFlow/Keras
#
# • Build first neural network
#
# • Understand backpropagation
#
# • Target: Deep learning basics

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt

# 1. Setup TensorFlow/Keras
print(f"TensorFlow version: {tf.__version__}")

# 2. Build First Neural Network
# We will use the MNIST dataset (handwritten digits) for this introductory task
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess data: Scale pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# Define the Architecture (Neural Network Basics)
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),    # Input layer
    layers.Dense(128, activation='relu'),      # Hidden layer 1
    layers.Dropout(0.2),                       # Regularization
    layers.Dense(10, activation='softmax')     # Output layer (10 digits)
])

# 3. Understand Backpropagation & Compilation
# The optimizer (Adam) handles the backpropagation process during training
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# 4. Train the Model
print("\nStarting training...")
history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))

# 5. Evaluate the Target: Deep learning basics
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
print(f'\nTest Accuracy: {test_acc*100:.2f}%')

# Visualization of Training Progress
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# TensorFlow version: 2.20.0
#
# Starting training...
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9137 - loss: 0.2966 - val_accuracy: 0.9594 - val_loss: 0.1400
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9586 - loss: 0.1424 - val_accuracy: 0.9702 - val_loss: 0.1008
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9678 - loss: 0.1060 - val_accuracy: 0.9736 - val_loss: 0.0851
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9740 - loss: 0.0859 - val_accuracy: 0.9759 - val_loss: 0.0781
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9777 - loss: 0.0737 - val_accuracy: 0.9771 - val_loss: 0.0710
# 313/313 - 1s - 4ms/step - accuracy: 0.9771 - loss: 0.0710
#
# Test Accuracy: 97.71%
